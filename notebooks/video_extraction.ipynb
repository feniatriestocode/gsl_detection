# %%
from google.colab import drive
import os

drive.mount('/content/drive')

ZIP_PATH = "/content/drive/MyDrive/gsl/GSL Dataset/GSL_continuous.tar.gz"

# List the first 15 files to see the naming convention
# !tar -tzf "{ZIP_PATH}" | head -n 15
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# GSL_continuous/
# GSL_continuous/extracted_annotations_YGEIA2.csv
# GSL_continuous/health1_signer2_rep1_sentences/
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0039.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0043.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0007.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0072.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0032.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0070.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0044.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0015.jpg
# ...

# %%
# Count all .jpg files in your extraction folder
# !ls drive/MyDrive/gsl/GSL\ Dataset/GSL_continuous/health1_signer2_rep1_sentences/sentences0004/
# Out:
# ls: cannot access 'drive/MyDrive/gsl/GSL Dataset/GSL_continuous/health1_signer2_rep1_sentences/sentences0004/': No such file or directory

# %%
# This searches for the first 5 JPGs anywhere in the archive
# !tar -tzf "{ZIP_PATH}" | grep ".jpg"
# Out:
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0039.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0043.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0007.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0072.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0032.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0070.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0044.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0015.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0016.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0000.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0035.jpg
# GSL_continuous/health1_signer2_rep1_sentences/sentences0004/frame_0023.jpg
# ...

# %%
# Create a folder on Drive for your eye-check
# !mkdir -p "/content/drive/MyDrive/eye_check"

# Copy the extracted samples there
# !cp /content/temp_samples/* "/content/drive/MyDrive/eye_check/"

print("Done! Now go to your Google Drive browser/folder and download the 'eye_check' folder.")
